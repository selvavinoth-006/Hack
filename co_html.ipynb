# %% [markdown]
# <a href="https://colab.research.google.com/github/selvavinoth-006/Hack/blob/main/co_html.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, HTML

html_content = """
<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>ScreenCare - Screen Time & Wellness Tracker</title>
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    <script src="https://cdn.jsdelivr.net/npm/chart.js"></script>
    <style>
        :root {
            --primary: #4361ee;
            --secondary: #3a0ca3;
            --accent: #f72585;
            --light: #f8f9fa;
            --dark: #212529;
            --success: #4cc9f0;
            --warning: #ffd166;
            --danger: #ef476f;
            --gray: #adb5bd;
            --productive: #4caf50;
            --non-productive: #ff5722;
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
            font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
        }

        body {
            background-color: #f5f7fb;
            color: var(--dark);
            line-height: 1.6;
        }

        .container {
            display: grid;
            grid-template-columns: 250px 1fr;
            min-height: 100vh;
        }

        /* Sidebar */
        .sidebar {
            background: linear-gradient(to bottom, var(--primary), var(--secondary));
            color: white;
            padding: 20px;
            position: fixed;
            width: 250px;
            height: 100%;
            overflow-y: auto;
        }

        .logo {
            display: flex;
            align-items: center;
            margin-bottom: 30px;
            padding-bottom: 20px;
            border-bottom: 1px solid rgba(255, 255, 255, 0.1);
        }

        .logo i {
            font-size: 28px;
            margin-right: 10px;
            color: var(--success);
        }

        .logo h1 {
            font-size: 22px;
            font-weight: 700;
        }

        .menu-item {
            display: flex;
            align-items: center;
            padding: 12px 15px;
            margin-bottom: 8px;
            border-radius: 8px;
            transition: all 0.3s;
            cursor: pointer;
        }

        .menu-item:hover, .menu-item.active {
            background-color: rgba(255, 255, 255, 0.1);
        }

        .menu-item i {
            margin-right: 10px;
            font-size: 18px;
        }

        /* Main Content */
        .main-content {
            grid-column: 2;
            padding: 20px 30px;
        }

        .header {
            display: flex;
            justify-content: space-between;
            align-items: center;
            margin-bottom: 30px;
            padding-bottom: 15px;
            border-bottom: 1px solid var(--gray);
        }

        .user-info {
            display: flex;
            align-items: center;
        }

        .user-info img {
            width: 45px;
            height: 45px;
            border-radius: 50%;
            margin-right: 15px;
            object-fit: cover;
            border: 2px solid var(--primary);
        }

        /* Dashboard Cards */
        .dashboard-cards {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(280px, 1fr));
            gap: 20px;
            margin-bottom: 30px;
        }

        .card {
            background: white;
            border-radius: 12px;
            padding: 20px;
            box-shadow: 0 4px 15px rgba(0, 0, 0, 0.05);
        }

        .stat-card {
            display: flex;
            flex-direction: column;
        }

        .stat-card i {
            font-size: 32px;
            margin-bottom: 15px;
            align-self: flex-start;
            padding: 12px;
            border-radius: 10px;
        }

        .screen-time i { color: var(--primary); background: rgba(67, 97, 238, 0.1); }
        .productive i { color: var(--productive); background: rgba(76, 175, 80, 0.1); }
        .non-productive i { color: var(--non-productive); background: rgba(255, 87, 34, 0.1); }
        .breaks i { color: var(--warning); background: rgba(255, 209, 102, 0.1); }

        .stat-card h3 {
            font-size: 28px;
            margin-bottom: 5px;
        }

        .stat-card p {
            color: var(--gray);
            font-size: 14px;
        }

        /* Charts */
        .charts {
            display: grid;
            grid-template-columns: 2fr 1fr;
            gap: 20px;
            margin-bottom: 30px;
        }

        .chart-container {
            background: white;
            border-radius: 12px;
            padding: 20px;
            box-shadow: 0 4px 15px rgba(0, 0, 0, 0.05);
        }

        .chart-title {
            font-size: 18px;
            margin-bottom: 15px;
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        /* Apps List */
        .apps-list {
            background: white;
            border-radius: 12px;
            padding: 20px;
            box-shadow: 0 4px 15px rgba(0, 0, 0, 0.05);
            margin-bottom: 30px;
        }

        .app-item {
            display: flex;
            align-items: center;
            padding: 12px 0;
            border-bottom: 1px solid #eee;
        }

        .app-item:last-child {
            border-bottom: none;
        }

        .app-icon {
            width: 40px;
            height: 40px;
            border-radius: 10px;
            margin-right: 15px;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 20px;
            color: white;
        }

        .app-details {
            flex: 1;
        }

        .app-name {
            font-weight: 600;
        }

        .app-category {
            font-size: 12px;
            color: var(--gray);
        }

        .app-time {
            font-weight: 600;
        }

        /* Reminders */
        .reminders {
            background: white;
            border-radius: 12px;
            padding: 20px;
            box-shadow: 0 4px 15px rgba(0, 0, 0, 0.05);
        }

        .reminder-item {
            display: flex;
            align-items: center;
            padding: 15px 0;
            border-bottom: 1px solid #eee;
        }

        .reminder-item:last-child {
            border-bottom: none;
        }

        .reminder-icon {
            width: 45px;
            height: 45px;
            border-radius: 50%;
            margin-right: 15px;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 20px;
            color: white;
            background: var(--accent);
        }

        .reminder-details {
            flex: 1;
        }

        .reminder-title {
            font-weight: 600;
            margin-bottom: 5px;
        }

        .reminder-desc {
            font-size: 13px;
            color: var(--gray);
        }

        .reminder-time {
            font-weight: 600;
            color: var(--accent);
        }

        /* Responsive */
        @media (max-width: 992px) {
            .container {
                grid-template-columns: 1fr;
            }

            .sidebar {
                position: relative;
                width: 100%;
                height: auto;
            }

            .main-content {
                grid-column: 1;
            }

            .charts {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 768px) {
            .dashboard-cards {
                grid-template-columns: 1fr;
            }
        }
    </style>
</head>
<body>
    <div class="container">
        <!-- Sidebar -->
        <div class="sidebar">
            <div class="logo">
                <i class="fas fa-desktop"></i>
                <h1>ScreenCare</h1>
            </div>

            <div class="menu-item active">
                <i class="fas fa-home"></i>
                <span>Dashboard</span>
            </div>
            <div class="menu-item">
                <i class="fas fa-chart-pie"></i>
                <span>Analytics</span>
            </div>
            <div class="menu-item">
                <i class="fas fa-clock"></i>
                <span>Screen Time</span>
            </div>
            <div class="menu-item">
                <i class="fas fa-heart"></i>
                <span>Wellness</span>
            </div>
            <div class="menu-item">
                <i class="fas fa-bell"></i>
                <span>Reminders</span>
            </div>
            <div class="menu-item">
                <i class="fas fa-cog"></i>
                <span>Settings</span>
            </div>
        </div>

        <!-- Main Content -->
        <div class="main-content">
            <div class="header">
                <h2>Dashboard</h2>
                <div class="user-info">
                    <img src="https://randomuser.me/api/portraits/women/44.jpg" alt="User">
                    <div>
                        <h4>Jessica Parker</h4>
                        <p>Last sync: 10 mins ago</p>
                    </div>
                </div>
            </div>

            <!-- Dashboard Cards -->
            <div class="dashboard-cards">
                <div class="card stat-card screen-time">
                    <i class="fas fa-laptop"></i>
                    <h3>4h 28m</h3>
                    <p>Total Screen Time Today</p>
                </div>

                <div class="card stat-card productive">
                    <i class="fas fa-check-circle"></i>
                    <h3>2h 45m</h3>
                    <p>Productive Time</p>
                </div>

                <div class="card stat-card non-productive">
                    <i class="fas fa-times-circle"></i>
                    <h3>1h 43m</h3>
                    <p>Non-Productive Time</p>
                </div>

                <div class="card stat-card breaks">
                    <i class="fas fa-coffee"></i>
                    <h3>5</h3>
                    <p>Breaks Taken</p>
                </div>
            </div>

            <!-- Charts -->
            <div class="charts">
                <div class="chart-container">
                    <div class="chart-title">
                        <h3>Screen Time Analysis</h3>
                        <select>
                            <option>Last 7 Days</option>
                            <option>Last 30 Days</option>
                        </select>
                    </div>
                    <canvas id="timeChart"></canvas>
                </div>

                <div class="chart-container">
                    <div class="chart-title">
                        <h3>App Categories</h3>
                    </div>
                    <canvas id="categoryChart"></canvas>
                </div>
            </div>

            <!-- Apps List -->
            <div class="apps-list">
                <div class="chart-title">
                    <h3>Top Applications</h3>
                    <a href="#">View All</a>
                </div>

                <div class="app-item">
                    <div class="app-icon" style="background-color: #1877F2;">
                        <i class="fab fa-chrome"></i>
                    </div>
                    <div class="app-details">
                        <div class="app-name">Chrome Browser</div>
                        <div class="app-category">Productive</div>
                    </div>
                    <div class="app-time">1h 25m</div>
                </div>

                <div class="app-item">
                    <div class="app-icon" style="background-color: #25D366;">
                        <i class="fab fa-whatsapp"></i>
                    </div>
                    <div class="app-details">
                        <div class="app-name">WhatsApp</div>
                        <div class="app-category">Social</div>
                    </div>
                    <div class="app-time">48m</div>
                </div>

                <div class="app-item">
                    <div class="app-icon" style="background-color: #FF4500;">
                        <i class="fab fa-figma"></i>
                    </div>
                    <div class="app-details">
                        <div class="app-name">Figma</div>
                        <div class="app-category">Design</div>
                    </div>
                    <div class="app-time">1h 10m</div>
                </div>

                <div class="app-item">
                    <div class="app-icon" style="background-color: #1DA1F2;">
                        <i class="fab fa-slack"></i>
                    </div>
                    <div class="app-details">
                        <div class="app-name">Slack</div>
                        <div class="app-category">Communication</div>
                    </div>
                    <div class="app-time">35m</div>
                </div>

                <div class="app-item">
                    <div class="app-icon" style="background-color: #E4405F;">
                        <i class="fab fa-instagram"></i>
                    </div>
                    <div class="app-details">
                        <div class="app-name">Instagram</div>
                        <div class="app-category">Social</div>
                    </div>
                    <div class="app-time">55m</div>
                </div>
            </div>

            <!-- Reminders -->
            <div class="reminders">
                <div class="chart-title">
                    <h3>Wellness Reminders</h3>
                    <a href="#">Settings</a>
                </div>

                <div class="reminder-item">
                    <div class="reminder-icon">
                        <i class="fas fa-eye"></i>
                    </div>
                    <div class="reminder-details">
                        <div class="reminder-title">Eye Exercise</div>
                        <div class="reminder-desc">Look away from screen for 20 seconds</div>
                    </div>
                    <div class="reminder-time">15:30</div>
                </div>

                <div class="reminder-item">
                    <div class="reminder-icon" style="background-color: var(--success);">
                        <i class="fas fa-tint"></i>
                    </div>
                    <div class="reminder-details">
                        <div class="reminder-title">Hydration Reminder</div>
                        <div class="reminder-desc">Time to drink a glass of water</div>
                    </div>
                    <div class="reminder-time">16:00</div>
                </div>

                <div class="reminder-item">
                    <div class="reminder-icon" style="background-color: var(--warning);">
                        <i class="fas fa-walking"></i>
                    </div>
                    <div class="reminder-details">
                        <div class="reminder-title">Stretch Break</div>
                        <div class="reminder-desc">Stand up and stretch for 5 minutes</div>
                    </div>
                    <div class="reminder-time">16:30</div>
                </div>
            </div>
        </div>
    </div>

    <script>
        // Initialize charts
        document.addEventListener('DOMContentLoaded', function() {
            // Screen Time Chart
            const timeCtx = document.getElementById('timeChart').getContext('2d');
            const timeChart = new Chart(timeCtx, {
                type: 'bar',
                data: {
                    labels: ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'],
                    datasets: [
                        {
                            label: 'Productive Time',
                            data: [3.2, 2.8, 4.1, 3.5, 2.9, 1.5, 1.2],
                            backgroundColor: 'rgba(76, 175, 80, 0.7)',
                            borderColor: 'rgba(76, 175, 80, 1)',
                            borderWidth: 1
                        },
                        {
                            label: 'Non-Productive Time',
                            data: [2.1, 1.8, 2.5, 2.0, 1.5, 2.3, 1.8],
                            backgroundColor: 'rgba(255, 87, 34, 0.7)',
                            borderColor: 'rgba(255, 87, 34, 1)',
                            borderWidth: 1
                        }
                    ]
                },
                options: {
                    responsive: true,
                    scales: {
                        y: {
                            beginAtZero: true,
                            title: {
                                display: true,
                                text: 'Hours'
                            }
                        }
                    }
                }
            });

            // Category Chart
            const categoryCtx = document.getElementById('categoryChart').getContext('2d');
            const categoryChart = new Chart(categoryCtx, {
                type: 'doughnut',
                data: {
                    labels: ['Productive', 'Social Media', 'Entertainment', 'Other'],
                    datasets: [{
                        data: [62, 18, 12, 8],
                        backgroundColor: [
                            'rgba(76, 175, 80, 0.8)',
                            'rgba(239, 71, 111, 0.8)',
                            'rgba(255, 152, 0, 0.8)',
                            'rgba(156, 39, 176, 0.8)'
                        ],
                        borderWidth: 1
                    }]
                },
                options: {
                    responsive: true,
                    plugins: {
                        legend: {
                            position: 'bottom'
                        }
                    }
                }
            });

            // Simulate a notification
            setTimeout(() => {
                if (confirm("ScreenCare: Time for a quick eye exercise! Look away from your screen for 20 seconds. Would you like to schedule a break?")) {
                    alert("Break scheduled in 5 minutes. Stay healthy!");
                }
            }, 3000);
        });
    </script>
</body>
</html>
"""

display(HTML(html_content))
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>ScreenCare - Screen Time & Wellness Tracker</title>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
#     <script src="https://cdn.jsdelivr.net/npm/chart.js"></script>
#     <style>
#         :root {
#             --primary: #4361ee;
#             --secondary: #3a0ca3;
#             --accent: #f72585;
#             --light: #f8f9fa;
#             --dark: #212529;
#             --success: #4cc9f0;
#             --warning: #ffd166;
#             --danger: #ef476f;
#             --gray: #adb5bd;
#             --productive: #4caf50;
#             --non-productive: #ff5722;
#         }
#
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
# ...
